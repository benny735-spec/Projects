# %%
pip install pandas;
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine("mysql+pymysql://root:Root@localhost:3306/caps")

# %%
orders=pd.read_sql ("SELECT * from orders;",engine)
orders
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  01-01-2016    03-01-2016
# 1            2         1212             4  01-01-2016    04-01-2016
# 2            3          523             4  02-01-2016    05-01-2016
# 3            4          175             4  03-01-2016    04-01-2016
# 4            5         1324             4  03-01-2016    06-01-2016
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  06-09-2018    06-09-2018
# 1611      1612            3             3  21-10-2018    21-10-2018
# 1612      1613            1             3  18-11-2018    18-11-2018
# 1613      1614          135             3  28-11-2018    28-11-2018
# 1614      1615          136             3  28-12-2018    28-12-2018
#
#      shipped_date  store_id  staff_id
# 0      03-01-2016         1         2
# 1      03-01-2016         2         6
# ...

# %%
ordersnew = pd.read_csv(r"C:\Users\USER\Downloads\DA Materials\orders (1).csv")

# %% [raw]
# ordersnew

# %%
orderstatus= ordersnew['order_status.1'].value_counts().reset_index()
orderstatus
# Out:
#   order_status.1  count
# 0      Delivered    987
# 1        Shipped    458
# 2        Pending    170

# %%
plt.bar(orderstatus['order_status.1'],orderstatus['count'])
plt.title('Order status Distribution')
plt.xlabel('Status')
plt.ylabel('No of orders')
# Out:
# Text(0, 0.5, 'No of orders')

# %%
Categorystatus=order_items['Product category'].value_counts().reset_index()
Categorystatus
# Out:
#       Product category  count
# 0    Cruisers Bicycles   1378
# 1       Mountain Bikes   1183
# 2    Children Bicycles    782
# 3     Comfort Bicycles    537
# 4           Road Bikes    374
# 5  Cyclocross Bicycles    256
# 6       Electric Bikes    212

# %%
plt.bar(Categorystatus['Product category'],Categorystatus['count'])
plt.title('Category wise Distribution')
plt.xlabel('Status')
plt.ylabel('No of orders')
plt.xticks(rotation=75)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Cruisers Bicycles'),
#   Text(1, 0, 'Mountain Bikes'),
#   Text(2, 0, 'Children Bicycles'),
#   Text(3, 0, 'Comfort Bicycles'),
#   Text(4, 0, 'Road Bikes'),
#   Text(5, 0, 'Cyclocross Bicycles'),
#   Text(6, 0, 'Electric Bikes')])

# %%
customercity=customers1['city'].value_counts().reset_index().head()
customercity
# Out:
#            city  count
# 0  Mount Vernon     20
# 1  Ballston Spa     17
# 2     Scarsdale     17
# 3   Canandaigua     14
# 4   Floral Park     13

# %%
plt.pie(customercity['count'],labels=customercity['city'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x230ab376350>,
# ...
#  [Text(0.7853226692826746, 0.770239122033369, 'Mount Vernon'),
#   Text(-0.6568744116584752, 0.8823355412247273, 'Ballston Spa'),
#   Text(-1.018296406155011, -0.416019746180141, 'Scarsdale'),
#   Text(0.021330415532508397, -1.0997931684517825, 'Canandaigua'),
#   Text(0.9631141727415584, -0.5314236448111278, 'Floral Park')],
#  [Text(0.4283578196087316, 0.42013043020001944, '24.7%'),
#   Text(-0.35829513363189547, 0.48127393157712395, '21.0%'),
#   Text(-0.5554344033572787, -0.22691986155280414, '21.0%'),
#   Text(0.011634772108640942, -0.5998871827918812, '17.3%'),
#   Text(0.5253350033135773, -0.28986744262425146, '16.0%')])

# %%
order_items=pd.read_sql("select *from order_items;",engine)
order_items
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount  \
# 0            1        1          20         1      599.99      0.20
# 1            1        2           8         2     1799.99      0.07
# 2            1        3          10         2     1549.00      0.05
# 3            1        4          16         2      599.99      0.05
# 4            1        5           4         1     2899.99      0.20
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2     2299.99      0.07
# 4718      1614        3         213         2      269.99      0.20
# 4719      1615        1         197         2     2299.99      0.20
# 4720      1615        2         214         1      899.99      0.07
# 4721      1615        3         182         1     2499.99      0.20
#
#       total_Sales                                   product_items  Category  \
# ...

# %%
customers1=pd.read_sql("select * from customers1;",engine)
customers1
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# 1444         1445       Ester   Acevedo              NA
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
orders.describe()
# Out:
#           order_id  customer_id  order_status     store_id     staff_id
# count  1615.000000  1615.000000   1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517      3.778947     1.892260     5.855108
# std     466.354658   443.229967      0.693430     0.558395     1.913899
# min       1.000000     1.000000      1.000000     1.000000     2.000000
# 25%     404.500000   237.000000      4.000000     2.000000     6.000000
# 50%     808.000000   638.000000      4.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000      4.000000     2.000000     7.000000
# max    1615.000000  1445.000000      4.000000     3.000000     9.000000

# %%
order_items.describe()
# Out:
#           order_id      item_id   product_id     quantity    list_price  \
# count  4722.000000  4722.000000  4722.000000  4722.000000   4722.000000
# mean    821.265354     2.262601    59.366158     1.498941   1212.707872
# std     465.152168     1.199129    67.312708     0.500052   1352.798257
# min       1.000000     1.000000     2.000000     1.000000     89.990000
# 25%     423.250000     1.000000    14.000000     1.000000    429.000000
# 50%     828.500000     2.000000    28.000000     1.000000    599.990000
# 75%    1226.000000     3.000000    84.000000     2.000000   1549.000000
# max    1615.000000     5.000000   315.000000     2.000000  11999.990000
#
#           discount   total_Sales     Category
# count  4722.000000   4722.000000  4722.000000
# mean      0.105373   1816.707181     3.767471
# std       0.058119   2228.162327     1.985901
# min       0.050000     89.790000     1.000000
# 25%       0.050000    539.780000     2.000000
# ...

# %%
customers1.describe()
# Out:
#        customer_id      zip_code
# count  1445.000000   1445.000000
# mean    723.000000  34200.015225
# std     417.279882  34733.933551
# min       1.000000  10002.000000
# 25%     362.000000  11419.000000
# 50%     723.000000  11967.000000
# 75%    1084.000000  76110.000000
# max    1445.000000  95993.000000

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_status   1615 non-null   int64
#  3   order_date     1615 non-null   object
#  4   required_date  1615 non-null   object
#  5   shipped_date   1445 non-null   object
#  6   store_id       1615 non-null   int64
#  7   staff_id       1615 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 101.1+ KB

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          4722 non-null   int64
#  1   item_id           4722 non-null   int64
#  2   product_id        4722 non-null   int64
#  3   quantity          4722 non-null   int64
#  4   list_price        4722 non-null   float64
#  5   discount          4722 non-null   float64
#  6   total_Sales       4722 non-null   float64
#  7   product_items     4722 non-null   object
#  8   Category          4722 non-null   int64
#  9   Product category  4722 non-null   object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 369.0+ KB

# %%
customers1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   object
#  2   last_name    1445 non-null   object
#  3   phone        1445 non-null   object
#  4   email        1445 non-null   object
#  5   street       1445 non-null   object
#  6   city         1445 non-null   object
#  7   state        1445 non-null   object
#  8   zip_code     1445 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 101.7+ KB

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'],dayfirst=True)

# %%
analysis_date = orders['order_date'].max() + pd.Timedelta(days=1)
analysis_date
# Out:
# Timestamp('2018-12-29 00:00:00')

# %%
recency = (
    orders
    .groupby('customer_id')['order_date']
    .max()
    .reset_index()
)
recency['recency'] = (analysis_date - recency['order_date']).dt.days
recency = recency[['customer_id', 'recency']]

# %%
frequency = (
    orders
    .groupby('customer_id')['order_id']
    .nunique()
    .reset_index(name='frequency')
)

# %%
order_value = pd.merge(
    orders[['order_id', 'customer_id']],
    order_items[['order_id', 'total_Sales']],
    on='order_id',
    how='inner'
)

# %%
monetary = (
    order_value
    .groupby('customer_id')['total_Sales']
    .sum()
    .reset_index(name='monetary')
)

# %%
rfm = recency.merge(frequency, on='customer_id') \
             .merge(monetary, on='customer_id')
rfm.head()
# Out:
#    customer_id  recency  frequency  monetary
# 0            1       41          3  30644.78
# 1            2      264          3  21652.87
# 2            3       69          3  26248.66
# 3            4      255          3  24197.81
# 4            5      256          3  19442.01

# %%
rfm.to_sql("customer_segments", engine, if_exists="replace", index=False)
# Out:
# 1445

# %%
customer_segments = pd.read_sql("SELECT * FROM customer_segments;",engine)
customer_segments
# Out:
#       customer_id  recency  frequency  monetary
# 0               1       41          3  30644.78
# 1               2      264          3  21652.87
# 2               3       69          3  26248.66
# 3               4      255          3  24197.81
# 4               5      256          3  19442.01
# ...           ...      ...        ...       ...
# 1440         1441      337          1  10497.61
# 1441         1442      517          1   7841.32
# 1442         1443      774          1  11237.59
# 1443         1444      739          1   1749.57
# 1444         1445      297          1   9999.78
#
# [1445 rows x 4 columns]
